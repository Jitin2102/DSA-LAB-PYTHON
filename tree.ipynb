# %% [markdown]
# #### **This notebook is about Tree Data Structure**

# %% [markdown]
# ### Tree Implementation

# %% [markdown]
# #### TREE: A tree is non-linear and a hierarchical data structure consisting of a collection of nodes connected by edges.
# ### ![image.png](attachment:image.png)
# #### Properties of Trees
# ##### • There is one and only one path between every pair of vertices in a tree.
# ##### • A tree with n vertices has n-1 edges.
# ##### • A graph is a tree if and if only if it is minimally connected.
# ##### • Any connected graph with n vertices and n-1 edges is a tree.
#
# #### Internal node: The node which has at least one child is called as an internal node.
# #### Leaf node: The node which does not have any child is called as a leaf node.
# ### Level
# ##### • In a tree, each step from top to bottom is called as level of a tree.
# ##### • The level count starts with 0 and increments by 1 at each level or step.
# ### ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Height
# ##### • Total number of edges that lies on the longest path from any leaf node to a particular node is called as height of that node.
# ##### • Height of a tree is the height of root node.
# ##### • Height of all leaf nodes = 0
# ### ![image.png](attachment:image.png)

# %% [markdown]
# #### Depth
# ##### • Total number of edges from root node to a particular node is called as depth of that node.
# ##### • Depth of a tree is the total number of edges from root node to a leaf node in the longest path.
# ##### • Depth of the root node = 0
# ##### • The terms “level” and “depth” are used interchangeably.
# ### ![image.png](attachment:image.png)

# %% [markdown]
# #### Subtree
# ##### • In a tree, each child from a node forms a subtree recursively.
# ##### • Every child node forms a subtree on its parent node.
# ### ![image.png](attachment:image.png)

# %% [markdown]
# ### BINARY TREES
# ##### A binary tree is a finite set of nodes which is either empty or consists of a root and two disjoint trees called left sub-tree and right sub-tree.
#
# #### Types Of Binary Trees
# ##### 1.	Full/ proper/ strict Binary tree:The tree can only be considered as the full binary tree if each node must contain either 0 or 2 children. The full binary tree can also be defined as the tree in which each node must contain 2 children except the leaf nodes.
# ### ![image.png](attachment:image.png)
# #### 2.	Complete Binary tree: The complete binary tree is a tree in which all the nodes are completely filled except the last level. In the last level, all the nodes must be as left as possible. In a complete binary tree, the nodes should be added from the left.
# ### ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### **Tree Traversals**
# ##### Traversal means visiting each node of a tree exactly once in a specific order.
#
# #### **Pre-order**
# ##### 1.Visit the root
# ##### 2.Traverse the left sub tree in pre-order
# ##### 3.Traverse the right sub tree in pre-order.
#
# #### **In-order**
# ##### 1.Traverse the left sub tree in in-order
# ##### 2.Visit the root
# ##### 3.Traverse the right sub tree in in-order.
#
# #### **Post-order**
# ##### 1.Traverse the left sub tree in post-order
# ##### 2.Traverse the right sub tree in post-order.
# ##### 3.Visit the root
# ![image.png](attachment:image.png)

# %% [markdown]
# ### **Binary Search Tree**
# ##### A Binary Search Tree (BST) is a special type of binary tree where:
# ##### •	Each node has at most 2 children.
# ##### •	For any node:
# ##### o	Left subtree has only nodes less than the node.
# ##### o	Right subtree has only nodes greater than the node.
#
# #### Each subtree must also be a BST itself.
# ### ![image.png](attachment:image.png)

# %% [markdown]
# #### **Operations**
# #### •	**Search**: Start at root, move left if key < root, right if key > root.
# #### •	**Insertion**: Place new node in correct position following BST property.
# #### •	**Deletion**:
# #### o	Case 1: Node is a leaf → remove directly.
# #### o	Case 2: Node has one child → replace with child.
# #### o	Case 3: Node has two children → replace with inorder successor/predecessor

# %% [markdown]
# #### **Why Use a BST?**
# ##### •	Efficient search, insert, and delete operations.
# ##### •	Average time complexity:
# ##### o	Search: O(log n)
# ##### o	Insert/Delete: O(log n)

# %% [markdown]
# #### **Insertion of a node in binary search tree**
# ### ![image.png](attachment:image.png)

# %% [markdown]
# ### **Deletion of a node from binary search tree**
# #### **•	Deletion of leaf node.**
# ### ![image.png](attachment:image.png)
# #### **•	Deletion of a node having one child**
# ### ![image-2.png](attachment:image-2.png)
# #### **•	Deletion of a node having two children**
# ### ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### **Implementation**

# %% [markdown]
# #### **Node**

# %%
class Node:
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None

# %% [markdown]
# #### **BST Insert Operation**

# %%
def insert(root, key):
    if root is None:
        return Node(key)

    if key < root.key:
        root.left = insert(root.left, key)
    else:
        root.right = insert(root.right, key)

    return root

# %% [markdown]
# ### **BST Search Operation**

# %%
def search(root, key):
    if root is None or root.key == key:
        return root

    if key < root.key:
        return search(root.left, key)
    else:
        return search(root.right, key)

# %% [markdown]
# ### **BST Delete Operation**

# %%
def findSuccessor(node):
    current = node
    while(current.left is not None):
        current = current.left
    return current

def delete(node, value):
    if node is None:
        return node
    if value < node.data:
        node.left = delete(node.left, value)
    elif value > node.data:
        node.right = delete(node.right, value)
    else:
        if node.left is None and node.right is None:
            node = None
        elif node.left is None:
            node = node.right
        elif node.right is None:
            node = node.left
    
        else:
            successor = findSuccessor(node.right)
            node.data = successor.data
            node.right = delete(node.right, successor.data)
    return node
